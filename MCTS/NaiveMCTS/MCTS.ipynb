# %%
import uuid
import random
import gym
import numpy as np
from math import sqrt, log

class Node:
    def __init__(self, state, action, action_space, reward, terminal):
        self.identifier = str(uuid.uuid1())
        self.parent_identifier = None
        self.children_identifiers = []
        self.untried_actions = list(range(action_space))
        self.state = state
        self.total_simulation_reward = 0
        self.num_visits = 0
        self.performance = 0
        self.action = action
        self.reward = reward
        self.terminal = terminal

    def __str__(self):
        return "{}: (action={}, visits={}, reward={:d}, ratio={:0.4f})".format(
                                                  self.state,
                                                  self.action,
                                                  self.num_visits,
                                                  int(self.total_simulation_reward),
                                                  self.performance)

    def untried_action(self):
        action = random.choice(self.untried_actions)
        self.untried_actions.remove(action)
        return action

def vertical_lines(last_node_flags):
    vertical_lines = []
    vertical_line = '\u2502'
    for last_node_flag in last_node_flags[0:-1]:
        if last_node_flag == False:
            vertical_lines.append(vertical_line + ' ' * 3)
        else:
            # space between vertical lines
            vertical_lines.append(' ' * 4)
    return ''.join(vertical_lines)

def horizontal_line(last_node_flags):
    horizontal_line = '\u251c\u2500\u2500 '
    horizontal_line_end = '\u2514\u2500\u2500 '
    if last_node_flags[-1]:
        return horizontal_line_end
    else:
        return horizontal_line

# %%
class Tree:
    def __init__(self):
        self.nodes = {}
        self.root = None

    def size(self):
        """Returns the number of nodes in the tree."""
        return len(self.nodes)

    def depth_info(self):
        """Calculates the maximum depth and average depth of the tree."""
        depths = []

        def calculate_depth(node, current_depth):
            depths.append(current_depth)
            for child_id in node.children_identifiers:
                calculate_depth(self.nodes[child_id], current_depth + 1)

        if self.root is not None:
            calculate_depth(self.root, 0)

        if depths:
            max_depth = max(depths)
            avg_depth = sum(depths) / len(depths)
            return max_depth, avg_depth
        else:
            return 0, 0  # In case the tree is empty

    def is_expandable(self, node):
        if node.terminal:
            return False
        if len(node.untried_actions) > 0:
            return True
        return False

    def iter(self, identifier, depth, last_node_flags):
        if identifier is None:
            node = self.root
        else:
            node = self.nodes[identifier]

        if depth == 0:
            yield "", node
        else:
            yield vertical_lines(last_node_flags) + horizontal_line(last_node_flags), node

        children = [self.nodes[identifier] for identifier in node.children_identifiers]
        last_index = len(children) - 1

        depth += 1
        for index, child in enumerate(children):
            last_node_flags.append(index == last_index)
            for edge, node in self.iter(child.identifier, depth, last_node_flags):
                yield edge, node
            last_node_flags.pop()

    def add_node(self, node, parent=None):
        self.nodes.update({node.identifier: node})

        if parent is None:
            self.root = node
            self.nodes[node.identifier].parent = None
        else:
            self.nodes[parent.identifier].children_identifiers.append(node.identifier)
            self.nodes[node.identifier].parent_identifier=parent.identifier

    def children(self, node):
        children = []
        for identifier in self.nodes[node.identifier].children_identifiers:
            children.append(self.nodes[identifier])
        return children

    def parent(self, node):
        parent_identifier = self.nodes[node.identifier].parent_identifier
        if parent_identifier is None:
            return None
        else:
            return self.nodes[parent_identifier]

    def show(self):
        lines = ""
        for edge, node in self.iter(identifier=None, depth=0, last_node_flags=[]):
            lines += "{}{}\n".format(edge, node)
        print(lines)

    def render_policy(self):
        node = self.tree.root
        path = []
        print("Rendering final policy...\n")

        while node and not node.terminal:
            print(node)
            path.append(node.state)
            node = max(self.tree.children(node), key=lambda n: n.num_visits)
        
        if node:
            print(node)
            path.append(node.state)
        
        print("\nFinal policy path (states):", path)

# %%
class MonteCarloTreeSearch:
    def __init__(self, env, tree):
        self.env = env
        self.tree = tree
        self.action_space = self.env.action_space.n
        self.epsilon = 0.3
        state = self.env.reset()
        self.tree.add_node(Node(state=state, action=None, action_space=self.action_space, reward=0, terminal=False))

    def expand(self, node):
        action = node.untried_action()
        state, reward, done, _, _ = self.env.step(action)
        new_node = Node(state=state, action=action, action_space=self.action_space, reward=reward, terminal=done)
        self.tree.add_node(new_node, node)
        return new_node

    def simulation_phase(self, node):
        """Simulate the result of a random policy."""
        if node.terminal:
            return node.reward
        while True:
            action = random.randint(0, self.action_space-1)
            state, reward, done, _, _ = self.env.step(action)
            if done:
                return reward

    def selection_phase(self):
        """Select the most promising node to expand."""
        node = self.tree.root
        while not node.terminal:
            if self.tree.is_expandable(node):
                return self.expand(node)
            else:
                node = random.choice(self.tree.children(node))
                state, reward, done, _, _ = self.env.step(node.action)
                assert node.state == state
        return node

    def selection_phase_epsilon(self):
        """Select the most promising node to expand using epsilon-greedy."""
        node = self.tree.root
        while not node.terminal:
            if self.tree.is_expandable(node):
                return self.expand(node)
            else:
                # Epsilon-greedy selection
                if random.random() < self.epsilon:
                    # Explore: choose a random child
                    node = random.choice(self.tree.children(node))
                else:
                    # Exploit: choose the best child based on performance
                    node = max(self.tree.children(node), key=lambda n: n.performance, default=None)
                
                # Take the action and update the state
                state, reward, done, _, _ = self.env.step(node.action)
                assert node.state == state

        return node
    
    def backpropagation_phase(self, node, value):
        """Propagate the result back through the tree."""
        while node:
            node.num_visits += 1
            node.total_simulation_reward += value
            node.performance = node.total_simulation_reward / node.num_visits
            node = self.tree.parent(node)

    def forward(self):
        self._forward(self.tree.root)

    def _forward(self, node):
        best_child = max(self.tree.children(node), key=lambda n: n.performance, default=None)
        
        print("****** {} ******".format(best_child.state))

        for child in self.tree.children(best_child):
            print("{}: {:0.4f}".format(child.state, child.performance))

        if best_child and len(self.tree.children(best_child)) > 0:
            self._forward(best_child)

    def render_policy(self):
        node = self.tree.root
        path = []
        directions = {0: 'Left', 1: 'Down', 2: 'Right', 3: 'Up'}
        print("Rendering final policy...\n")
        
        # Close the current environment if open and reset with rendering enabled
        self.env.close()
        self.env = gym.make('FrozenLake-v1', is_slippery=True, render_mode='human')
        self.env.reset()

        while node and not node.terminal:
            self.env.render()
            path.append(node.state)
            children = self.tree.children(node)
            
            if not children:
                print("No more actions available.")
                break
            
            best_child = max(children, key=lambda n: n.performance, default=None)
            if best_child is not None and best_child.action is not None:
                print(f"Action: {directions.get(best_child.action, 'Unknown')} -> State: {best_child.state}")
                self.env.step(best_child.action)  # Take the action in the environment
                node = best_child
            else:
                print("No best child found.")
                break

        # Final rendering after reaching the goal
        self.env.render()
        self.env.close()    
        
        path2 = [item[0] if isinstance(item, tuple) else item for item in path]
        print(f"\nFinal policy path (states): {path2}")
        
        return path2

# %% [markdown]
# Training e testing

# %%
import random
from gym.envs.registration import register
import gym
from math import sqrt
import json

def init_env():
    register(
        id='FrozenLakeNotSlippery-v0',
        entry_point='gym.envs.toy_text:FrozenLakeEnv',
        kwargs={'map_name': '4x4', 'is_slippery': False}
    )
    return gym.make('FrozenLakeNotSlippery-v0')

def main():
    random.seed(2)
    env = init_env()
    steps_values = [1000, 5000, 10000]  # Example steps values
   
    results = []

    for steps in steps_values:
        
        print(f"\nRunning MCTS with steps: {steps}\n")

        tree = Tree()
        monteCarloTreeSearch = MonteCarloTreeSearch(env=env, tree=tree)

        for _ in range(0, steps):
            env.reset()
            node = monteCarloTreeSearch.selection_phase_epsilon()
            reward = monteCarloTreeSearch.simulation_phase(node) 
            monteCarloTreeSearch.backpropagation_phase(node, reward)  
            #monteCarloTreeSearch.tree.show()

        # Measure and display tree statistics
        tree_size = tree.size()
        max_depth, avg_depth = tree.depth_info()

        print(f"Tree size: {tree_size}")
        print(f"Maximum depth: {max_depth}")
        print(f"Average depth: {avg_depth:.2f}")

        monteCarloTreeSearch.tree.show()
        monteCarloTreeSearch.forward()
        policy_path = monteCarloTreeSearch.render_policy()

        print(f"Final policy path: {policy_path}")

        # Save the results for this combination
        results.append({
            'steps': steps,
            'tree_size': tree_size,
            'max_depth': max_depth,
            'avg_depth': avg_depth,
            'policy_path': policy_path
        })

    # # Save results to a JSON file
    # with open('simulations/mcts_results.json', 'w') as json_file:
    #     json.dump(results, json_file, indent=4)

if __name__ == "__main__":
    main()
# Out:
# Running MCTS with steps: 1000
#
# Tree size: 541
# Maximum depth: 12
# Average depth: 5.62
# (0, {'prob': 1}): (action=None, visits=1000, reward=181, ratio=0.1810)
# ├── 0: (action=0, visits=71, reward=1, ratio=0.0141)
# │   ├── 0: (action=0, visits=51, reward=1, ratio=0.0196)
# │   │   ├── 1: (action=2, visits=33, reward=1, ratio=0.0303)
# │   │   │   ├── 5: (action=1, visits=16, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=3, visits=11, reward=1, ratio=0.0909)
# │   │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=2, visits=5, reward=1, ratio=0.2000)
# │   │   │   │       ├── 6: (action=1, visits=1, reward=1, ratio=1.0000)
# │   │   │   │       ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 2: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │       └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=6, reward=0, ratio=0.0000)
# │   │   ├── 5: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   ├── 0: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │   ├── 1: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   └── 1: (action=2, visits=6, reward=0, ratio=0.0000)
# │       ├── 1: (action=3, visits=2, reward=0, ratio=0.0000)
# │       │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │       └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# ├── 0: (action=3, visits=91, reward=1, ratio=0.0110)
# │   ├── 4: (action=1, visits=60, reward=0, ratio=0.0000)
# │   │   ├── 5: (action=2, visits=44, reward=0, ratio=0.0000)
# │   │   ├── 8: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=6, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   └── 4: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │       ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   ├── 0: (action=3, visits=21, reward=1, ratio=0.0476)
# │   │   ├── 0: (action=0, visits=16, reward=1, ratio=0.0625)
# │   │   │   ├── 0: (action=0, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=9, reward=1, ratio=0.1111)
# │   │   │   │   ├── 0: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │       └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   └── 1: (action=2, visits=5, reward=0, ratio=0.0000)
# │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# ├── 4: (action=1, visits=760, reward=179, ratio=0.2355)
# │   ├── 0: (action=3, visits=150, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=0, visits=118, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=88, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=65, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=0, visits=50, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 1: (action=2, visits=38, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 0: (action=0, visits=28, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   ├── 0: (action=3, visits=19, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   ├── 4: (action=1, visits=12, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   ├── 5: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   ├── 0: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   └── 8: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │       └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   ├── 1: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   └── 0: (action=0, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   ├── 4: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   └── 1: (action=2, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 5: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 2: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   └── 1: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 0: (action=0, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 4: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   │   │       ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=3, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 4: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 1: (action=2, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   │       ├── 2: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │       │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=9, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 1: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=2, visits=6, reward=0, ratio=0.0000)
# │   │   │   │       ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │       │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=8, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=9, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 4: (action=1, visits=12, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │       │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=1, visits=11, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=0, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 1: (action=2, visits=9, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=3, visits=11, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 4: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │       │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   ├── 5: (action=2, visits=58, reward=0, ratio=0.0000)
# │   ├── 8: (action=1, visits=474, reward=177, ratio=0.3734)
# │   │   ├── 8: (action=0, visits=99, reward=15, ratio=0.1515)
# │   │   │   ├── 9: (action=2, visits=68, reward=15, ratio=0.2206)
# │   │   │   │   ├── 5: (action=3, visits=8, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=0, visits=7, reward=1, ratio=0.1429)
# │   │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 9: (action=2, visits=3, reward=1, ratio=0.3333)
# │   │   │   │   │       ├── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       └── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 13: (action=1, visits=43, reward=13, ratio=0.3023)
# │   │   │   │   │   ├── 12: (action=0, visits=9, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 14: (action=2, visits=4, reward=1, ratio=0.2500)
# │   │   │   │   │   │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │   │   │   │   │   └── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 9: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 5: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 13: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 13: (action=1, visits=22, reward=11, ratio=0.5000)
# │   │   │   │   │       ├── 14: (action=2, visits=14, reward=11, ratio=0.7857)
# │   │   │   │   │       │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       │   ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       │   ├── 14: (action=1, visits=4, reward=3, ratio=0.7500)
# │   │   │   │   │       │   │   ├── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │   │   │   │       │   │   ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       │   │   └── 13: (action=0, visits=1, reward=1, ratio=1.0000)
# │   │   │   │   │       │   └── 15: (action=2, visits=7, reward=7, ratio=1.0000)
# │   │   │   │   │       ├── 9: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │       │   ├── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       ├── 13: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │       │   └── 12: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │       └── 12: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   └── 10: (action=2, visits=9, reward=1, ratio=0.1111)
# │   │   │   │       ├── 14: (action=1, visits=5, reward=1, ratio=0.2000)
# │   │   │   │       │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       │   ├── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       │   ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       │   └── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │   │   │       ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       ├── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       └── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 12: (action=1, visits=9, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=0, visits=13, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=0, visits=8, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 9: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │       └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 4: (action=3, visits=8, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=2, visits=3, reward=0, ratio=0.0000)
# │   │   │       ├── 8: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │       │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=3, visits=36, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=2, visits=24, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 12: (action=1, visits=47, reward=0, ratio=0.0000)
# │   │   └── 9: (action=2, visits=291, reward=162, ratio=0.5567)
# │   │       ├── 10: (action=2, visits=215, reward=147, ratio=0.6837)
# │   │       │   ├── 14: (action=1, visits=167, reward=140, ratio=0.8383)
# │   │       │   │   ├── 14: (action=1, visits=14, reward=7, ratio=0.5000)
# │   │       │   │   │   ├── 14: (action=1, visits=2, reward=1, ratio=0.5000)
# │   │       │   │   │   │   └── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │       │   │   │   ├── 13: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │       │   │   │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   ├── 10: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │       │   │   │   │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   └── 15: (action=2, visits=6, reward=6, ratio=1.0000)
# │   │       │   │   ├── 13: (action=0, visits=13, reward=4, ratio=0.3077)
# │   │       │   │   │   ├── 12: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   ├── 13: (action=1, visits=3, reward=1, ratio=0.3333)
# │   │       │   │   │   │   ├── 9: (action=3, visits=1, reward=1, ratio=1.0000)
# │   │       │   │   │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   ├── 9: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │   │   │   │   └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   └── 14: (action=2, visits=6, reward=3, ratio=0.5000)
# │   │       │   │   │       ├── 10: (action=3, visits=2, reward=1, ratio=0.5000)
# │   │       │   │   │       │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │       ├── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │       │   │   │       ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │       └── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   ├── 15: (action=2, visits=125, reward=125, ratio=1.0000)
# │   │       │   │   └── 10: (action=3, visits=14, reward=3, ratio=0.2143)
# │   │       │   │       ├── 14: (action=1, visits=8, reward=3, ratio=0.3750)
# │   │       │   │       │   ├── 10: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │   │       │   │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   │       │   ├── 13: (action=0, visits=2, reward=1, ratio=0.5000)
# │   │       │   │       │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   │       │   ├── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   │       │   └── 15: (action=2, visits=2, reward=2, ratio=1.0000)
# │   │       │   │       ├── 11: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │       │   │       ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │       └── 6: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │   │           └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 11: (action=2, visits=12, reward=0, ratio=0.0000)
# │   │       │   ├── 6: (action=3, visits=15, reward=3, ratio=0.2000)
# │   │       │   │   ├── 2: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   ├── 10: (action=1, visits=9, reward=3, ratio=0.3333)
# │   │       │   │   │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   ├── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   ├── 14: (action=1, visits=3, reward=2, ratio=0.6667)
# │   │       │   │   │   │   ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │   │   └── 14: (action=1, visits=1, reward=1, ratio=1.0000)
# │   │       │   │   │   └── 6: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │       │   │   │       ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   │       └── 5: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   ├── 7: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │       │   │   └── 5: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 9: (action=0, visits=20, reward=4, ratio=0.2000)
# │   │       │       ├── 8: (action=0, visits=10, reward=2, ratio=0.2000)
# │   │       │       │   ├── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │       │       │   ├── 8: (action=0, visits=4, reward=2, ratio=0.5000)
# │   │       │       │   │   ├── 8: (action=0, visits=1, reward=1, ratio=1.0000)
# │   │       │       │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │       │   │   └── 9: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │       │       │   ├── 4: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │       │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │       │   └── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │       ├── 5: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │       ├── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │       └── 10: (action=2, visits=6, reward=2, ratio=0.3333)
# │   │       │           ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │           ├── 6: (action=3, visits=2, reward=1, ratio=0.5000)
# │   │       │           │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │           ├── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │           └── 14: (action=1, visits=1, reward=1, ratio=1.0000)
# │   │       ├── 5: (action=3, visits=18, reward=0, ratio=0.0000)
# │   │       ├── 13: (action=1, visits=30, reward=15, ratio=0.5000)
# │   │       │   ├── 12: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │       │   ├── 13: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │       │   │   ├── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 9: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │       │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   │   └── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 14: (action=2, visits=21, reward=15, ratio=0.7143)
# │   │       │       ├── 14: (action=1, visits=3, reward=1, ratio=0.3333)
# │   │       │       │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │       │   └── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │       │       ├── 13: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │       │       │   └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │       ├── 10: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │       │       │   └── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │       └── 15: (action=2, visits=13, reward=13, ratio=1.0000)
# │   │       └── 8: (action=0, visits=27, reward=0, ratio=0.0000)
# │   │           ├── 9: (action=2, visits=17, reward=0, ratio=0.0000)
# │   │           │   ├── 5: (action=3, visits=9, reward=0, ratio=0.0000)
# │   │           │   ├── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │           │   ├── 10: (action=2, visits=3, reward=0, ratio=0.0000)
# │   │           │   │   ├── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │           │   │   └── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │           │   └── 8: (action=0, visits=3, reward=0, ratio=0.0000)
# │   │           │       ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │           │       └── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │           ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │           ├── 8: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │           │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │           └── 12: (action=1, visits=6, reward=0, ratio=0.0000)
# │   └── 4: (action=0, visits=77, reward=1, ratio=0.0130)
# │       ├── 4: (action=0, visits=48, reward=1, ratio=0.0208)
# │       │   ├── 8: (action=1, visits=34, reward=1, ratio=0.0294)
# │       │   │   ├── 8: (action=0, visits=23, reward=1, ratio=0.0435)
# │       │   │   │   ├── 8: (action=0, visits=12, reward=0, ratio=0.0000)
# │       │   │   │   │   ├── 8: (action=0, visits=5, reward=0, ratio=0.0000)
# │       │   │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   │   │   └── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   │   ├── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# │       │   │   │   │   ├── 4: (action=3, visits=2, reward=0, ratio=0.0000)
# │       │   │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   │   └── 9: (action=2, visits=2, reward=0, ratio=0.0000)
# │       │   │   │   │       └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   ├── 9: (action=2, visits=3, reward=0, ratio=0.0000)
# │       │   │   │   │   ├── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   │   ├── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# │       │   │   │   └── 4: (action=3, visits=5, reward=0, ratio=0.0000)
# │       │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   │       ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   │       └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 12: (action=1, visits=4, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=3, visits=2, reward=0, ratio=0.0000)
# │       │   │   │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 9: (action=2, visits=4, reward=0, ratio=0.0000)
# │       │   │       ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │       ├── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │       └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
# │       │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │       │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   └── 5: (action=2, visits=4, reward=0, ratio=0.0000)
# │       ├── 0: (action=3, visits=12, reward=0, ratio=0.0000)
# │       │   ├── 0: (action=0, visits=6, reward=0, ratio=0.0000)
# │       │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │       │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │       │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   └── 4: (action=1, visits=2, reward=0, ratio=0.0000)
# │       │       └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │       ├── 5: (action=2, visits=7, reward=0, ratio=0.0000)
# │       └── 8: (action=1, visits=9, reward=0, ratio=0.0000)
# │           ├── 8: (action=0, visits=3, reward=0, ratio=0.0000)
# │           │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │           ├── 9: (action=2, visits=2, reward=0, ratio=0.0000)
# │           │   └── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │           ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │           └── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# └── 1: (action=2, visits=78, reward=0, ratio=0.0000)
#     ├── 1: (action=3, visits=58, reward=0, ratio=0.0000)
#     │   ├── 2: (action=2, visits=39, reward=0, ratio=0.0000)
#     │   │   ├── 2: (action=3, visits=25, reward=0, ratio=0.0000)
#     │   │   │   ├── 2: (action=3, visits=17, reward=0, ratio=0.0000)
#     │   │   │   │   ├── 2: (action=3, visits=10, reward=0, ratio=0.0000)
#     │   │   │   │   │   ├── 6: (action=1, visits=6, reward=0, ratio=0.0000)
#     │   │   │   │   │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   │   │   ├── 5: (action=0, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   │   │   ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   │   │   └── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   ├── 1: (action=0, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │   └── 3: (action=2, visits=3, reward=0, ratio=0.0000)
#     │   │   │   │       ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   │       └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 1: (action=0, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 6: (action=1, visits=3, reward=0, ratio=0.0000)
#     │   │   │       ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │       └── 10: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 3: (action=2, visits=3, reward=0, ratio=0.0000)
#     │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 6: (action=1, visits=6, reward=0, ratio=0.0000)
#     │   │   │   ├── 2: (action=3, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 5: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 1: (action=0, visits=4, reward=0, ratio=0.0000)
#     │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   ├── 5: (action=1, visits=8, reward=0, ratio=0.0000)
#     │   ├── 0: (action=0, visits=6, reward=0, ratio=0.0000)
#     │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 1: (action=2, visits=2, reward=0, ratio=0.0000)
#     │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   └── 1: (action=3, visits=4, reward=0, ratio=0.0000)
#     │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#     ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
#     │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     ├── 5: (action=1, visits=8, reward=0, ratio=0.0000)
#     └── 2: (action=2, visits=9, reward=0, ratio=0.0000)
#         ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
#         │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#         ├── 2: (action=3, visits=3, reward=0, ratio=0.0000)
#         │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         └── 6: (action=1, visits=2, reward=0, ratio=0.0000)
#             └── 10: (action=1, visits=1, reward=0, ratio=0.0000)
#
# ****** 4 ******
# 0: 0.0000
# 5: 0.0000
# 8: 0.3734
# 4: 0.0130
# ****** 8 ******
# 8: 0.1515
# 4: 0.0000
# 12: 0.0000
# 9: 0.5567
# ****** 9 ******
# 10: 0.6837
# 5: 0.0000
# 13: 0.5000
# 8: 0.0000
# ****** 10 ******
# 14: 0.8383
# 11: 0.0000
# 6: 0.2000
# 9: 0.2000
# ****** 14 ******
# 14: 0.5000
# 13: 0.3077
# 15: 1.0000
# 10: 0.2143
# ****** 15 ******
# Rendering final policy...
#
# Action: Down -> State: 4
# Action: Down -> State: 8
# Action: Right -> State: 9
# Action: Right -> State: 10
# Action: Down -> State: 14
# Action: Right -> State: 15
#
# Final policy path (states): [0, 4, 8, 9, 10, 14]
# Final policy path: [0, 4, 8, 9, 10, 14]
#
# Running MCTS with steps: 5000
#
# Tree size: 2164
# Maximum depth: 14
# Average depth: 7.19
# (0, {'prob': 1}): (action=None, visits=5000, reward=993, ratio=0.1986)
# ├── 0: (action=3, visits=483, reward=3, ratio=0.0062)
# │   ├── 1: (action=2, visits=149, reward=1, ratio=0.0067)
# │   │   ├── 1: (action=3, visits=114, reward=1, ratio=0.0088)
# │   │   │   ├── 5: (action=1, visits=14, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=11, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │   │   │       ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 2: (action=2, visits=83, reward=1, ratio=0.0120)
# │   │   │       ├── 3: (action=2, visits=6, reward=0, ratio=0.0000)
# │   │   │       │   ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │       │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 2: (action=3, visits=56, reward=1, ratio=0.0179)
# │   │   │       │   ├── 1: (action=0, visits=40, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 5: (action=1, visits=30, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 1: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │       │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 0: (action=0, visits=3, reward=0, ratio=0.0000)
# │   │   │       │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   └── 2: (action=2, visits=3, reward=0, ratio=0.0000)
# │   │   │       │   │       ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │       └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 2: (action=3, visits=10, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 3: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │   │       │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   │   ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 1: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │       │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 3: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   └── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=0, visits=8, reward=0, ratio=0.0000)
# │   │   │       │   ├── 2: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 6: (action=1, visits=12, reward=0, ratio=0.0000)
# │   │   │           ├── 7: (action=2, visits=7, reward=0, ratio=0.0000)
# │   │   │           ├── 5: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │           ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │           └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 2: (action=2, visits=12, reward=0, ratio=0.0000)
# │   │   │   ├── 3: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 6: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 5: (action=1, visits=14, reward=0, ratio=0.0000)
# │   │   └── 0: (action=0, visits=8, reward=0, ratio=0.0000)
# │   │       ├── 4: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │       │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       └── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │           └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   ├── 0: (action=3, visits=151, reward=1, ratio=0.0066)
# │   │   ├── 0: (action=0, visits=113, reward=1, ratio=0.0088)
# │   │   │   ├── 0: (action=0, visits=12, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=3, reward=0, ratio=0.0000)
# │   │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=81, reward=1, ratio=0.0123)
# │   │   │   │   ├── 1: (action=3, visits=51, reward=1, ratio=0.0196)
# │   │   │   │   │   ├── 0: (action=0, visits=41, reward=0, ratio=0.0000)
# │   │   │   │   │   │   ├── 1: (action=2, visits=35, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   ├── 0: (action=0, visits=26, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   ├── 0: (action=0, visits=15, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   ├── 0: (action=0, visits=9, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   ├── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   ├── 1: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   │   │   │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# ...
#         │   │   │   │   │   │   ├── 2: (action=3, visits=53, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   ├── 3: (action=2, visits=41, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   ├── 3: (action=3, visits=28, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   ├── 7: (action=1, visits=16, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   ├── 3: (action=2, visits=3, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   ├── 2: (action=0, visits=5, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   └── 3: (action=3, visits=3, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │       ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │       └── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   ├── 3: (action=2, visits=3, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   ├── 7: (action=1, visits=4, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   └── 2: (action=0, visits=5, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │       ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │       ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │       ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │       └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   ├── 6: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   ├── 2: (action=3, visits=5, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   └── 1: (action=0, visits=4, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   ├── 5: (action=0, visits=4, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   ├── 10: (action=1, visits=6, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   ├── 11: (action=2, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   ├── 14: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   └── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   ├── 2: (action=3, visits=3, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   ├── 1: (action=0, visits=4, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   └── 3: (action=2, visits=8, reward=0, ratio=0.0000)
#         │   │   │   │   │       ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │       │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │       ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │       ├── 7: (action=1, visits=3, reward=0, ratio=0.0000)
#         │   │   │   │   │       └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 3: (action=3, visits=7, reward=0, ratio=0.0000)
#         │   │   │   │   │   ├── 2: (action=0, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   │   ├── 7: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 7: (action=1, visits=7, reward=0, ratio=0.0000)
#         │   │   │   │   └── 3: (action=2, visits=7, reward=0, ratio=0.0000)
#         │   │   │   │       ├── 7: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │       ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │       ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │       │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │       └── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 1: (action=0, visits=9, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 5: (action=1, visits=4, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 1: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 6: (action=1, visits=10, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 5: (action=0, visits=6, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   └── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 2: (action=3, visits=9, reward=0, ratio=0.0000)
#         │   │   │       ├── 6: (action=1, visits=3, reward=0, ratio=0.0000)
#         │   │   │       │   ├── 5: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │       │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │       ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │       ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
#         │   │   │       │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │       └── 2: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │   │           └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 6: (action=1, visits=13, reward=0, ratio=0.0000)
#         │   │   │   ├── 7: (action=2, visits=8, reward=0, ratio=0.0000)
#         │   │   │   ├── 10: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 5: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 1: (action=0, visits=12, reward=0, ratio=0.0000)
#         │   │   │   ├── 0: (action=0, visits=7, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 4: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 1: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │   │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 3: (action=2, visits=14, reward=0, ratio=0.0000)
#         │   │       ├── 2: (action=0, visits=9, reward=0, ratio=0.0000)
#         │   │       │   ├── 2: (action=3, visits=4, reward=0, ratio=0.0000)
#         │   │       │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │       │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │       │   │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │       │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │       │   ├── 3: (action=2, visits=2, reward=0, ratio=0.0000)
#         │   │       │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │       │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │       ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │       ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │       └── 3: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │           └── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   ├── 6: (action=1, visits=24, reward=2, ratio=0.0833)
#         │   │   ├── 2: (action=3, visits=14, reward=2, ratio=0.1429)
#         │   │   │   ├── 1: (action=0, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 2: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │   │   │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 6: (action=1, visits=8, reward=2, ratio=0.2500)
#         │   │   │       ├── 10: (action=1, visits=3, reward=2, ratio=0.6667)
#         │   │   │       │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │       │   └── 14: (action=1, visits=1, reward=1, ratio=1.0000)
#         │   │   │       ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │       ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │       └── 5: (action=0, visits=2, reward=0, ratio=0.0000)
#         │   │   ├── 10: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   │   └── 9: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 5: (action=0, visits=6, reward=0, ratio=0.0000)
#         │   ├── 3: (action=2, visits=17, reward=0, ratio=0.0000)
#         │   │   ├── 3: (action=2, visits=8, reward=0, ratio=0.0000)
#         │   │   │   ├── 7: (action=1, visits=4, reward=0, ratio=0.0000)
#         │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 3: (action=3, visits=4, reward=0, ratio=0.0000)
#         │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 7: (action=1, visits=2, reward=0, ratio=0.0000)
#         │   │   └── 2: (action=0, visits=2, reward=0, ratio=0.0000)
#         │   │       └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   └── 1: (action=0, visits=18, reward=0, ratio=0.0000)
#         │       ├── 5: (action=1, visits=13, reward=0, ratio=0.0000)
#         │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │       ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#         │       └── 2: (action=2, visits=2, reward=0, ratio=0.0000)
#         │           └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#         ├── 5: (action=1, visits=22, reward=0, ratio=0.0000)
#         ├── 1: (action=3, visits=20, reward=0, ratio=0.0000)
#         │   ├── 0: (action=0, visits=12, reward=0, ratio=0.0000)
#         │   │   ├── 1: (action=2, visits=8, reward=0, ratio=0.0000)
#         │   │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   ├── 5: (action=1, visits=3, reward=0, ratio=0.0000)
#         │   ├── 1: (action=3, visits=2, reward=0, ratio=0.0000)
#         │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   └── 2: (action=2, visits=2, reward=0, ratio=0.0000)
#         │       └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#         └── 0: (action=0, visits=22, reward=0, ratio=0.0000)
#             ├── 0: (action=3, visits=11, reward=0, ratio=0.0000)
#             │   ├── 1: (action=2, visits=5, reward=0, ratio=0.0000)
#             │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#             │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#             │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#             │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#             │   ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
#             │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#             │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
#             │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#             │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#             ├── 4: (action=1, visits=4, reward=0, ratio=0.0000)
#             │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#             │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#             │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#             ├── 0: (action=0, visits=3, reward=0, ratio=0.0000)
#             │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#             │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#             └── 1: (action=2, visits=3, reward=0, ratio=0.0000)
#                 ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#                 └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#
# ****** 4 ******
# 5: 0.0000
# 0: 0.0454
# 8: 0.5797
# 4: 0.2572
# ****** 8 ******
# 8: 0.4283
# 9: 0.7044
# 4: 0.0268
# 12: 0.0000
# ****** 9 ******
# 13: 0.8108
# 5: 0.0000
# 8: 0.3754
# 10: 0.6395
# ****** 13 ******
# 9: 0.2456
# 12: 0.0000
# 13: 0.7059
# 14: 0.9466
# ****** 14 ******
# 15: 1.0000
# 14: 0.8670
# 10: 0.7092
# 13: 0.6196
# ****** 15 ******
# Rendering final policy...
#
# Action: Down -> State: 4
# Action: Down -> State: 8
# Action: Right -> State: 9
# Action: Down -> State: 13
# Action: Right -> State: 14
# Action: Right -> State: 15
#
# Final policy path (states): [0, 4, 8, 9, 13, 14]
# Final policy path: [0, 4, 8, 9, 13, 14]

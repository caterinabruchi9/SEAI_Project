# %%
import uuid
import random
import gym
import numpy as np
from math import sqrt, log

class Node:
    def __init__(self, state, action, action_space, reward, terminal):
        self.identifier = str(uuid.uuid1())
        self.parent_identifier = None
        self.children_identifiers = []
        self.untried_actions = list(range(action_space))
        self.state = state
        self.total_simulation_reward = 0
        self.num_visits = 0
        self.performance = 0
        self.action = action
        self.reward = reward
        self.terminal = terminal

    def __str__(self):
        return "{}: (action={}, visits={}, reward={:d}, ratio={:0.4f})".format(
                                                  self.state,
                                                  self.action,
                                                  self.num_visits,
                                                  int(self.total_simulation_reward),
                                                  self.performance)

    def untried_action(self):
        action = random.choice(self.untried_actions)
        self.untried_actions.remove(action)
        return action

def vertical_lines(last_node_flags):
    vertical_lines = []
    vertical_line = '\u2502'
    for last_node_flag in last_node_flags[0:-1]:
        if last_node_flag == False:
            vertical_lines.append(vertical_line + ' ' * 3)
        else:
            vertical_lines.append(' ' * 4)
    return ''.join(vertical_lines)

def horizontal_line(last_node_flags):
    horizontal_line = '\u251c\u2500\u2500 '
    horizontal_line_end = '\u2514\u2500\u2500 '
    if last_node_flags[-1]:
        return horizontal_line_end
    else:
        return horizontal_line

class Tree:
    def __init__(self):
        self.nodes = {}
        self.root = None

    def is_expandable(self, node):
        if node.terminal:
            return False
        if len(node.untried_actions) > 0:
            return True
        return False

    def iter(self, identifier, depth, last_node_flags):
        if identifier is None:
            node = self.root
        else:
            node = self.nodes[identifier]

        if depth == 0:
            yield "", node
        else:
            yield vertical_lines(last_node_flags) + horizontal_line(last_node_flags), node

        children = [self.nodes[identifier] for identifier in node.children_identifiers]
        last_index = len(children) - 1

        depth += 1
        for index, child in enumerate(children):
            last_node_flags.append(index == last_index)
            for edge, node in self.iter(child.identifier, depth, last_node_flags):
                yield edge, node
            last_node_flags.pop()

    def add_node(self, node, parent=None):
        self.nodes.update({node.identifier: node})

        if parent is None:
            self.root = node
            self.nodes[node.identifier].parent = None
        else:
            self.nodes[parent.identifier].children_identifiers.append(node.identifier)
            self.nodes[node.identifier].parent_identifier = parent.identifier

    def children(self, node):
        children = []
        for identifier in self.nodes[node.identifier].children_identifiers:
            children.append(self.nodes[identifier])
        return children

    def parent(self, node):
        parent_identifier = self.nodes[node.identifier].parent_identifier
        if parent_identifier is None:
            return None
        else:
            return self.nodes[parent_identifier]

    def show(self):
        lines = ""
        for edge, node in self.iter(identifier=None, depth=0, last_node_flags=[]):
            lines += "{}{}\n".format(edge, node)
        print(lines)

    def render_policy(self):
        node = self.tree.root
        path = []
        print("Rendering final policy...\n")

        while node and not node.terminal:
            print(node)
            path.append(node.state)
            node = max(self.tree.children(node), key=lambda n: n.num_visits)
        
        if node:
            print(node)
            path.append(node.state)
        
        print("\nFinal policy path (states):", path)

# %%
import numpy as np

def compute_v_table_from_q_table(q_table_file):

    # Carica la Q-table dal file
    q_table = np.load(q_table_file)
    q_table = q_table[0]
    v_table = np.max(q_table, axis=1)
    np.save("V.npy", v_table)
    return v_table

# %%
class MonteCarloTreeSearch:
    def __init__(self, env, V, initial_state=None, max_steps=2):
        self.env = env
        self.V = V  # Value matrix
        self.action_space = self.env.action_space.n
        self.max_steps = max_steps  # Maximum steps to simulate forward
        self.initial_state = initial_state
        self.reset_tree()

    def reset_tree(self):
        """Reset the tree with the given state as the root."""
        if self.initial_state is None:
            state = self.env.reset()[0]
        else:
            self.env.reset()  # Reset the environment to the start.
            self.env.unwrapped.s = self.initial_state  # Manually set the state to initial_state.
            state = self.initial_state
        
        root_node = Node(state=state, action=None, action_space=self.action_space, reward=0, terminal=False)
        self.tree = Tree()
        self.tree.add_node(root_node)
        print("Root node:", root_node)

    def expand(self, node, action):
        """Expand a given node by taking an action."""
        previous_state = self.env.unwrapped.s
        
        state, reward, done, _, _ = self.env.step(action)
        new_node = Node(state=state, action=action, action_space=self.action_space, reward=self.V[state], terminal=done)
        self.tree.add_node(new_node, node)

        self.env.unwrapped.s = previous_state

        return new_node

    def simulate(self, node):
        return self.V[node.state]


    def backpropagate(self, node, reward):
        """Backpropagate the simulation results up the tree."""
        while node:
            node.num_visits += 1
            node.total_simulation_reward += reward
            node.performance = node.total_simulation_reward / node.num_visits
            node.reward = (node.reward + 0.99 * reward)/ node.num_visits # Discount reward for parent
            node = self.tree.parent(node)

    def build_depth_n_tree(self):
        """Expand the tree to depth max_steps and perform simulations."""
        root_node = self.tree.root
        
        for action in range(self.action_space):
            child_node = self.expand(root_node, action)
            print(f"Expanded root node {root_node} with action {action}, resulting in state {child_node.state}")
            
            if not child_node.terminal:
                for second_action in range(self.action_space):
                    grandchild_node = self.expand(child_node, second_action)
                    print(f"  Expanded child node {child_node.state} with action {second_action}, resulting in state {grandchild_node.state}")
                    
                    simulation_reward = self.simulate(child_node)
                    print(f"  Simulated from state {child_node.state}, got reward {simulation_reward}")
                    
                    self.backpropagate(child_node, simulation_reward)
        
            self.env.unwrapped.s = root_node.state  # Reset the environment to the root state
        self.tree.show()  # Visualize the tree after building

    def forward(self):
        """Perform a single iteration of MCTS with depth-n simulation as default policy."""
        self.build_depth_n_tree()
        root_node = self.tree.root
        best_child = max(self.tree.children(root_node), key=lambda n: n.reward, default=None)
        if best_child:
            return best_child.action, best_child.state
        else:
            return None, None

    def run(self):
        """Run a single iteration, now reflecting the deeper default policy."""
        self.forward()

    def choose_best_action(self):
        """After running the MCTS, choose the best action based on the highest value of the final state."""
        children = self.tree.children(self.tree.root)
        
        # Check if any child has the state equal to 15
        for child in children:
            if child.state == 15:
                return child.action, child.state
        
        # If no child state is 15, choose the one with the highest performance
        best_child = max(children, key=lambda n: n.performance, default=None)
        
        if best_child:
            return best_child.action, best_child.state
        else:
            return None, None



def main():
    env = gym.make('FrozenLake-v1', is_slippery=False)
    env2 = gym.make('FrozenLake-v1', is_slippery=False)

    q_table_file = 'Q.npy'
    v_table = compute_v_table_from_q_table(q_table_file)
    
    print("V-table:", v_table)
    
    target_state = 15
    
    stateMCTS = env.reset()[0]
    print(f"Initial state: {stateMCTS}")
    env2.reset()[0]
    
    path = [stateMCTS]
    terminal_state_reached = False
    max_iterations_without_convergence = 1000
    iteration_count = 0

    print("Starting MCTS...")
    while not terminal_state_reached and iteration_count < max_iterations_without_convergence:
        monteCarloTreeSearch = MonteCarloTreeSearch(env=env, V=v_table, initial_state=stateMCTS, max_steps=2)  # Adjust max_steps as needed
        monteCarloTreeSearch.run()
        print(f"\nBuilt tree for the cell\n")
        monteCarloTreeSearch.tree.show()
        
        action, next_state = monteCarloTreeSearch.choose_best_action()

        if action is None:
            print("No valid actions found, stopping.")
            break

        print(f"Chosen action: {action}, leads to state: {next_state}")
        path.append(next_state)

        env2_state, reward, done, _, _ = env2.step(action)
        print(f"New state after action {action}: {env2_state}, reward: {reward}, done: {done}")

        if env2_state == target_state:
            print("Target state reached.")
            terminal_state_reached = True
        elif done:
            print("Fell into the lake, retrying.")
            stateMCTS = env.reset()[0] 
            env2.reset()  
            path = [stateMCTS]
            iteration_count = 0  
        else:
            stateMCTS = env2_state
            iteration_count += 1

    print("\nFinal path (states):", path)
    if terminal_state_reached:
        path = []

   

if __name__ == "__main__":
    main()
# Out:
# V-table: [0.95099005 0.96059601 0.97029794 0.96059601 0.96059601 0.
#  0.9801     0.         0.970299   0.9801     0.99       0.
#  0.         0.99       1.         0.        ]
# Initial state: 0
# Starting MCTS...
# Root node: 0: (action=None, visits=0, reward=0, ratio=0.0000)
# Expanded root node 0: (action=None, visits=0, reward=0, ratio=0.0000) with action 0, resulting in state 0
#   Expanded child node 0 with action 0, resulting in state 0
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 1, resulting in state 4
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 2, resulting in state 1
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 3, resulting in state 0
#   Simulated from state 0, got reward 0.9509900498999999
# Expanded root node 0: (action=None, visits=4, reward=3, ratio=0.9510) with action 1, resulting in state 4
#   Expanded child node 4 with action 0, resulting in state 0
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 1, resulting in state 4
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 2, resulting in state 1
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 3, resulting in state 0
#   Simulated from state 4, got reward 0.96059601
# Expanded root node 0: (action=None, visits=8, reward=7, ratio=0.9558) with action 2, resulting in state 1
#   Expanded child node 1 with action 0, resulting in state 0
#   Simulated from state 1, got reward 0.96059601
#   Expanded child node 1 with action 1, resulting in state 4
#   Simulated from state 1, got reward 0.96059601
#   Expanded child node 1 with action 2, resulting in state 1
#   Simulated from state 1, got reward 0.96059601
#   Expanded child node 1 with action 3, resulting in state 0
#   Simulated from state 1, got reward 0.96059601
# Expanded root node 0: (action=None, visits=12, reward=11, ratio=0.9574) with action 3, resulting in state 0
#   Expanded child node 0 with action 0, resulting in state 0
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 1, resulting in state 4
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 2, resulting in state 1
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 3, resulting in state 0
#   Simulated from state 0, got reward 0.9509900498999999
# 0: (action=None, visits=16, reward=15, ratio=0.9558)
# ├── 0: (action=0, visits=4, reward=3, ratio=0.9510)
# │   ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 4: (action=1, visits=4, reward=3, ratio=0.9606)
# │   ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 1: (action=2, visits=4, reward=3, ratio=0.9606)
# │   ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 0: (action=3, visits=4, reward=3, ratio=0.9510)
#     ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
#
#
# Built tree for the cell
#
# 0: (action=None, visits=16, reward=15, ratio=0.9558)
# ├── 0: (action=0, visits=4, reward=3, ratio=0.9510)
# │   ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 4: (action=1, visits=4, reward=3, ratio=0.9606)
# │   ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 1: (action=2, visits=4, reward=3, ratio=0.9606)
# │   ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 0: (action=3, visits=4, reward=3, ratio=0.9510)
#     ├── 0: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 4: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 1: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
#
# Chosen action: 1, leads to state: 4
# New state after action 1: 4, reward: 0.0, done: False
# Root node: 4: (action=None, visits=0, reward=0, ratio=0.0000)
# Expanded root node 4: (action=None, visits=0, reward=0, ratio=0.0000) with action 0, resulting in state 4
#   Expanded child node 4 with action 0, resulting in state 4
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 1, resulting in state 8
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 2, resulting in state 5
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 3, resulting in state 0
#   Simulated from state 4, got reward 0.96059601
# Expanded root node 4: (action=None, visits=4, reward=3, ratio=0.9606) with action 1, resulting in state 8
#   Expanded child node 8 with action 0, resulting in state 4
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 1, resulting in state 8
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 2, resulting in state 5
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 3, resulting in state 0
#   Simulated from state 8, got reward 0.9702989999999999
# Expanded root node 4: (action=None, visits=8, reward=7, ratio=0.9654) with action 2, resulting in state 5
# Expanded root node 4: (action=None, visits=8, reward=7, ratio=0.9654) with action 3, resulting in state 0
#   Expanded child node 0 with action 0, resulting in state 4
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 1, resulting in state 8
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 2, resulting in state 5
#   Simulated from state 0, got reward 0.9509900498999999
#   Expanded child node 0 with action 3, resulting in state 0
#   Simulated from state 0, got reward 0.9509900498999999
# 4: (action=None, visits=12, reward=11, ratio=0.9606)
# ├── 4: (action=0, visits=4, reward=3, ratio=0.9606)
# │   ├── 4: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 8: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 8: (action=1, visits=4, reward=3, ratio=0.9703)
# │   ├── 4: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 8: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
# └── 0: (action=3, visits=4, reward=3, ratio=0.9510)
#     ├── 4: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 8: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
#
#
# Built tree for the cell
#
# 4: (action=None, visits=12, reward=11, ratio=0.9606)
# ├── 4: (action=0, visits=4, reward=3, ratio=0.9606)
# │   ├── 4: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 8: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 8: (action=1, visits=4, reward=3, ratio=0.9703)
# │   ├── 4: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 8: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
# └── 0: (action=3, visits=4, reward=3, ratio=0.9510)
#     ├── 4: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 8: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 5: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 0: (action=3, visits=0, reward=0, ratio=0.0000)
#
# Chosen action: 1, leads to state: 8
# New state after action 1: 8, reward: 0.0, done: False
# Root node: 8: (action=None, visits=0, reward=0, ratio=0.0000)
# Expanded root node 8: (action=None, visits=0, reward=0, ratio=0.0000) with action 0, resulting in state 8
#   Expanded child node 8 with action 0, resulting in state 8
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 1, resulting in state 12
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 2, resulting in state 9
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 3, resulting in state 4
#   Simulated from state 8, got reward 0.9702989999999999
# Expanded root node 8: (action=None, visits=4, reward=3, ratio=0.9703) with action 1, resulting in state 12
# Expanded root node 8: (action=None, visits=4, reward=3, ratio=0.9703) with action 2, resulting in state 9
#   Expanded child node 9 with action 0, resulting in state 8
#   Simulated from state 9, got reward 0.9801
#   Expanded child node 9 with action 1, resulting in state 12
#   Simulated from state 9, got reward 0.9801
#   Expanded child node 9 with action 2, resulting in state 9
#   Simulated from state 9, got reward 0.9801
#   Expanded child node 9 with action 3, resulting in state 4
#   Simulated from state 9, got reward 0.9801
# Expanded root node 8: (action=None, visits=8, reward=7, ratio=0.9752) with action 3, resulting in state 4
#   Expanded child node 4 with action 0, resulting in state 8
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 1, resulting in state 12
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 2, resulting in state 9
#   Simulated from state 4, got reward 0.96059601
#   Expanded child node 4 with action 3, resulting in state 4
#   Simulated from state 4, got reward 0.96059601
# 8: (action=None, visits=12, reward=11, ratio=0.9703)
# ├── 8: (action=0, visits=4, reward=3, ratio=0.9703)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 9: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 4: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
# ├── 9: (action=2, visits=4, reward=3, ratio=0.9801)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 9: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 4: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 4: (action=3, visits=4, reward=3, ratio=0.9606)
#     ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 9: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 4: (action=3, visits=0, reward=0, ratio=0.0000)
#
#
# Built tree for the cell
#
# 8: (action=None, visits=12, reward=11, ratio=0.9703)
# ├── 8: (action=0, visits=4, reward=3, ratio=0.9703)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 9: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 4: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
# ├── 9: (action=2, visits=4, reward=3, ratio=0.9801)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 9: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 4: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 4: (action=3, visits=4, reward=3, ratio=0.9606)
#     ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 12: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 9: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 4: (action=3, visits=0, reward=0, ratio=0.0000)
#
# Chosen action: 2, leads to state: 9
# New state after action 2: 9, reward: 0.0, done: False
# Root node: 9: (action=None, visits=0, reward=0, ratio=0.0000)
# Expanded root node 9: (action=None, visits=0, reward=0, ratio=0.0000) with action 0, resulting in state 8
#   Expanded child node 8 with action 0, resulting in state 8
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 1, resulting in state 13
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 2, resulting in state 10
#   Simulated from state 8, got reward 0.9702989999999999
#   Expanded child node 8 with action 3, resulting in state 5
#   Simulated from state 8, got reward 0.9702989999999999
# Expanded root node 9: (action=None, visits=4, reward=3, ratio=0.9703) with action 1, resulting in state 13
#   Expanded child node 13 with action 0, resulting in state 8
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 1, resulting in state 13
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 2, resulting in state 10
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 3, resulting in state 5
#   Simulated from state 13, got reward 0.99
# Expanded root node 9: (action=None, visits=8, reward=7, ratio=0.9801) with action 2, resulting in state 10
#   Expanded child node 10 with action 0, resulting in state 8
#   Simulated from state 10, got reward 0.99
#   Expanded child node 10 with action 1, resulting in state 13
#   Simulated from state 10, got reward 0.99
#   Expanded child node 10 with action 2, resulting in state 10
#   Simulated from state 10, got reward 0.99
#   Expanded child node 10 with action 3, resulting in state 5
#   Simulated from state 10, got reward 0.99
# Expanded root node 9: (action=None, visits=12, reward=11, ratio=0.9834) with action 3, resulting in state 5
# 9: (action=None, visits=12, reward=11, ratio=0.9834)
# ├── 8: (action=0, visits=4, reward=3, ratio=0.9703)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 10: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 13: (action=1, visits=4, reward=3, ratio=0.9900)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 10: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 10: (action=2, visits=4, reward=3, ratio=0.9900)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 10: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
#
#
# Built tree for the cell
#
# 9: (action=None, visits=12, reward=11, ratio=0.9834)
# ├── 8: (action=0, visits=4, reward=3, ratio=0.9703)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 10: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 13: (action=1, visits=4, reward=3, ratio=0.9900)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 10: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 10: (action=2, visits=4, reward=3, ratio=0.9900)
# │   ├── 8: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 10: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 5: (action=3, visits=0, reward=0, ratio=0.0000)
#
# Chosen action: 1, leads to state: 13
# New state after action 1: 13, reward: 0.0, done: False
# Root node: 13: (action=None, visits=0, reward=0, ratio=0.0000)
# Expanded root node 13: (action=None, visits=0, reward=0, ratio=0.0000) with action 0, resulting in state 12
# Expanded root node 13: (action=None, visits=0, reward=0, ratio=0.0000) with action 1, resulting in state 13
#   Expanded child node 13 with action 0, resulting in state 12
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 1, resulting in state 13
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 2, resulting in state 14
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 3, resulting in state 9
#   Simulated from state 13, got reward 0.99
# Expanded root node 13: (action=None, visits=4, reward=3, ratio=0.9900) with action 2, resulting in state 14
#   Expanded child node 14 with action 0, resulting in state 12
#   Simulated from state 14, got reward 1.0
#   Expanded child node 14 with action 1, resulting in state 13
#   Simulated from state 14, got reward 1.0
#   Expanded child node 14 with action 2, resulting in state 14
#   Simulated from state 14, got reward 1.0
#   Expanded child node 14 with action 3, resulting in state 9
#   Simulated from state 14, got reward 1.0
# Expanded root node 13: (action=None, visits=8, reward=7, ratio=0.9950) with action 3, resulting in state 9
#   Expanded child node 9 with action 0, resulting in state 12
#   Simulated from state 9, got reward 0.9801
#   Expanded child node 9 with action 1, resulting in state 13
#   Simulated from state 9, got reward 0.9801
#   Expanded child node 9 with action 2, resulting in state 14
#   Simulated from state 9, got reward 0.9801
#   Expanded child node 9 with action 3, resulting in state 9
#   Simulated from state 9, got reward 0.9801
# 13: (action=None, visits=12, reward=11, ratio=0.9900)
# ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
# ├── 13: (action=1, visits=4, reward=3, ratio=0.9900)
# │   ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 9: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 14: (action=2, visits=4, reward=4, ratio=1.0000)
# │   ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 9: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 9: (action=3, visits=4, reward=3, ratio=0.9801)
#     ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 14: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 9: (action=3, visits=0, reward=0, ratio=0.0000)
#
#
# Built tree for the cell
#
# 13: (action=None, visits=12, reward=11, ratio=0.9900)
# ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
# ├── 13: (action=1, visits=4, reward=3, ratio=0.9900)
# │   ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 9: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 14: (action=2, visits=4, reward=4, ratio=1.0000)
# │   ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 9: (action=3, visits=0, reward=0, ratio=0.0000)
# └── 9: (action=3, visits=4, reward=3, ratio=0.9801)
#     ├── 12: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 13: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 14: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 9: (action=3, visits=0, reward=0, ratio=0.0000)
#
# Chosen action: 2, leads to state: 14
# New state after action 2: 14, reward: 0.0, done: False
# Root node: 14: (action=None, visits=0, reward=0, ratio=0.0000)
# Expanded root node 14: (action=None, visits=0, reward=0, ratio=0.0000) with action 0, resulting in state 13
#   Expanded child node 13 with action 0, resulting in state 13
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 1, resulting in state 14
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 2, resulting in state 15
#   Simulated from state 13, got reward 0.99
#   Expanded child node 13 with action 3, resulting in state 10
#   Simulated from state 13, got reward 0.99
# Expanded root node 14: (action=None, visits=4, reward=3, ratio=0.9900) with action 1, resulting in state 14
#   Expanded child node 14 with action 0, resulting in state 13
#   Simulated from state 14, got reward 1.0
#   Expanded child node 14 with action 1, resulting in state 14
#   Simulated from state 14, got reward 1.0
#   Expanded child node 14 with action 2, resulting in state 15
#   Simulated from state 14, got reward 1.0
#   Expanded child node 14 with action 3, resulting in state 10
#   Simulated from state 14, got reward 1.0
# Expanded root node 14: (action=None, visits=8, reward=7, ratio=0.9950) with action 2, resulting in state 15
# Expanded root node 14: (action=None, visits=8, reward=7, ratio=0.9950) with action 3, resulting in state 10
#   Expanded child node 10 with action 0, resulting in state 13
#   Simulated from state 10, got reward 0.99
#   Expanded child node 10 with action 1, resulting in state 14
#   Simulated from state 10, got reward 0.99
#   Expanded child node 10 with action 2, resulting in state 15
#   Simulated from state 10, got reward 0.99
#   Expanded child node 10 with action 3, resulting in state 10
#   Simulated from state 10, got reward 0.99
# 14: (action=None, visits=12, reward=11, ratio=0.9933)
# ├── 13: (action=0, visits=4, reward=3, ratio=0.9900)
# │   ├── 13: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 10: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 14: (action=1, visits=4, reward=4, ratio=1.0000)
# │   ├── 13: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 10: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
# └── 10: (action=3, visits=4, reward=3, ratio=0.9900)
#     ├── 13: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 14: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 10: (action=3, visits=0, reward=0, ratio=0.0000)
#
#
# Built tree for the cell
#
# 14: (action=None, visits=12, reward=11, ratio=0.9933)
# ├── 13: (action=0, visits=4, reward=3, ratio=0.9900)
# │   ├── 13: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 10: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 14: (action=1, visits=4, reward=4, ratio=1.0000)
# │   ├── 13: (action=0, visits=0, reward=0, ratio=0.0000)
# │   ├── 14: (action=1, visits=0, reward=0, ratio=0.0000)
# │   ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
# │   └── 10: (action=3, visits=0, reward=0, ratio=0.0000)
# ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
# └── 10: (action=3, visits=4, reward=3, ratio=0.9900)
#     ├── 13: (action=0, visits=0, reward=0, ratio=0.0000)
#     ├── 14: (action=1, visits=0, reward=0, ratio=0.0000)
#     ├── 15: (action=2, visits=0, reward=0, ratio=0.0000)
#     └── 10: (action=3, visits=0, reward=0, ratio=0.0000)
#
# Chosen action: 2, leads to state: 15
# New state after action 2: 15, reward: 1.0, done: True
# Target state reached.
#
# Final path (states): [0, 4, 8, 9, 13, 14, 15]

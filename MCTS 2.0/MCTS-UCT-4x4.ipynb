# %% [markdown]
# # Versione originale con UCT

# %%
import uuid
import random

class Node:

    def __init__(self, state, action, action_space, reward, terminal):
        self.identifier = str(uuid.uuid1())
        self.parent_identifier = None
        self.children_identifiers = []
        self.untried_actions = list(range(action_space))
        self.state = state
        self.total_simulation_reward = 0
        self.num_visits = 0
        self.performance = 0
        self.action = action
        self.reward = reward
        self.terminal = terminal

    def __str__(self):
        return "{}: (action={}, visits={}, reward={:d}, ratio={:0.4f})".format(
                                                  self.state,
                                                  self.action,
                                                  self.num_visits,
                                                  int(self.total_simulation_reward),
                                                  self.performance)

    def untried_action(self):
        action = random.choice(self.untried_actions)
        self.untried_actions.remove(action)
        return action
    
def vertical_lines(last_node_flags):
    vertical_lines = []
    vertical_line = '\u2502'
    for last_node_flag in last_node_flags[0:-1]:
        if last_node_flag == False:
            vertical_lines.append(vertical_line + ' ' * 3)
        else:
            # space between vertical lines
            vertical_lines.append(' ' * 4)
    return ''.join(vertical_lines)

def horizontal_line(last_node_flags):
    horizontal_line = '\u251c\u2500\u2500 '
    horizontal_line_end = '\u2514\u2500\u2500 '
    if last_node_flags[-1]:
        return horizontal_line_end
    else:
        return horizontal_line

class Tree:

    def __init__(self):
        self.nodes = {}
        self.root = None

    def is_expandable(self, node):
        if node.terminal:
            return False
        if len(node.untried_actions) > 0:
            return True
        return False

    def iter(self, identifier, depth, last_node_flags):
        if identifier is None:
            node = self.root
        else:
            node = self.nodes[identifier]

        if depth == 0:
            yield "", node
        else:
            yield vertical_lines(last_node_flags) + horizontal_line(last_node_flags), node

        children = [self.nodes[identifier] for identifier in node.children_identifiers]
        last_index = len(children) - 1

        depth += 1
        for index, child in enumerate(children):
            last_node_flags.append(index == last_index)
            for edge, node in self.iter(child.identifier, depth, last_node_flags):
                yield edge, node
            last_node_flags.pop()

    def add_node(self, node, parent=None):
        self.nodes.update({node.identifier: node})

        if parent is None:
            self.root = node
            self.nodes[node.identifier].parent = None
        else:
            self.nodes[parent.identifier].children_identifiers.append(node.identifier)
            self.nodes[node.identifier].parent_identifier=parent.identifier

    def children(self, node):
        children = []
        for identifier in self.nodes[node.identifier].children_identifiers:
            children.append(self.nodes[identifier])
        return children

    def parent(self, node):
        parent_identifier = self.nodes[node.identifier].parent_identifier
        if parent_identifier is None:
            return None
        else:
            return self.nodes[parent_identifier]

    def show(self):
        lines = ""
        for edge, node in self.iter(identifier=None, depth=0, last_node_flags=[]):
            lines += "{}{}\n".format(edge, node)
        print(lines)

    def render_policy(self):
        """
        Render the final policy obtained from the MCTS process.
        The policy is derived by following the most visited child at each node.
        """
        node = self.tree.root
        path = []
        print("Rendering final policy...\n")

        while node and not node.terminal:
            print(node)
            path.append(node.state)
            node = max(self.tree.children(node), key=lambda n: n.num_visits)
        
        if node:
            print(node)
            path.append(node.state)
        
        print("\nFinal policy path (states):", path)

import random
from math import sqrt, log
import gym
import numpy as np


class MonteCarloTreeSearch():

    def __init__(self, env, tree):
        self.env = env
        self.tree = tree
        self.action_space = self.env.action_space.n
        state = self.env.reset()
        self.tree.add_node(Node(state=state, action=None, action_space=self.action_space, reward=0, terminal=False))

    def expand(self, node):
        action = node.untried_action()
        state, reward, done, _, _ = self.env.step(action)
        new_node = Node(state=state, action=action, action_space=self.action_space, reward=reward, terminal=done)
        self.tree.add_node(new_node, node)
        return new_node

    def default_policy(self, node):
        if node.terminal:
            return node.reward

        while True:
            action = random.randint(0, self.action_space-1)
            state, reward, done, _, _ = self.env.step(action)
            if done:
                return reward

    def compute_value(self, parent, child, exploration_constant):
        exploitation_term = child.total_simulation_reward / child.num_visits
        exploration_term = exploration_constant * sqrt(2 * log(parent.num_visits) / child.num_visits)
        return exploitation_term + exploration_term

    def best_child(self, node, exploration_constant):
        best_child = self.tree.children(node)[0]
        best_value = self.compute_value(node, best_child, exploration_constant)
        iter_children = iter(self.tree.children(node))
        next(iter_children)
        for child in iter_children:
            value = self.compute_value(node, child, exploration_constant)
            if value > best_value:
                best_child = child
                best_value = value
        return best_child

    def tree_policy(self):
        node = self.tree.root
        while not node.terminal:
            if self.tree.is_expandable(node):
                return self.expand(node)
            else:
                node = self.best_child(node, exploration_constant=1.0/sqrt(2.0))
                state, reward, done, _, _ = self.env.step(node.action)
                assert node.state == state
        return node

    def backward(self, node, value):
        while node:
            node.num_visits += 1
            node.total_simulation_reward += value
            node.performance = node.total_simulation_reward/node.num_visits
            node = self.tree.parent(node)

    def forward(self):
        self._forward(self.tree.root)

    def _forward(self,node):
        best_child = self.best_child(node, exploration_constant=1.4)

        print("****** {} ******".format(best_child.state))

        for child in self.tree.children(best_child):
            print("{}: {:0.4f}".format(child.state, child.performance))

        if len(self.tree.children(best_child)) > 0:
            self._forward(best_child)

    def render_policy(self, map_size):
        """
        Render the final policy obtained from the MCTS process using the gym's render function.
        """
        node = self.tree.root
        path = []
        directions = {0: 'Left', 1: 'Down', 2: 'Right', 3: 'Up'}
        
        print("Rendering final policy...\n")
        
        # Close the current environment if open and reset with rendering enabled
        self.env.close()
        self.env = gym.make('FrozenLake-v1', is_slippery=False, render_mode='human', map_name=map_size)
        self.env.reset()

        # Traverse the tree to follow the best path
        while node and not node.terminal:
            self.env.render()
            path.append(node.state)
            best_child = max(self.tree.children(node), key=lambda n: n.num_visits)
            if best_child.action is not None:
                print(f"Action: {directions[best_child.action]} -> State: {best_child.state}")
                self.env.step(best_child.action)  # Take the action in the environment
            node = best_child

        # Final rendering after reaching the goal
        self.env.render()
        self.env.close()    
        print(f"\nFinal policy path (states): {path}")
        
        path2 = [item[0] if isinstance(item, tuple) else item for item in path]

        print(path2)
        return path2

# %%
import random
from gym.envs.registration import register
import gym
import matplotlib.pyplot as plt

def main():
    map_name='4x4'
    env = gym.make('FrozenLake-v1', is_slippery=False, map_name=map_name)
    tree = Tree()
    monteCarloTreeSearch = MonteCarloTreeSearch(env=env, tree=tree)
    steps = 10000

    for _ in range(0, steps):
        env.reset()
        node = monteCarloTreeSearch.tree_policy()
        reward = monteCarloTreeSearch.default_policy(node)
        monteCarloTreeSearch.backward(node, reward)

    monteCarloTreeSearch.tree.show()
    monteCarloTreeSearch.forward()
    monteCarloTreeSearch.render_policy(map_name)
    
    
   


if __name__ == "__main__":
   main()
# Out:
# (0, {'prob': 1}): (action=None, visits=10000, reward=8591, ratio=0.8591)
# ├── 4: (action=1, visits=9007, reward=8574, ratio=0.9519)
# │   ├── 0: (action=3, visits=99, reward=4, ratio=0.0404)
# │   │   ├── 4: (action=1, visits=28, reward=2, ratio=0.0714)
# │   │   │   ├── 5: (action=2, visits=6, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=8, reward=1, ratio=0.1250)
# │   │   │   │   ├── 1: (action=2, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 8: (action=1, visits=8, reward=1, ratio=0.1250)
# │   │   │       ├── 8: (action=0, visits=3, reward=1, ratio=0.3333)
# │   │   │       │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 1: (action=2, visits=25, reward=1, ratio=0.0400)
# │   │   │   ├── 1: (action=3, visits=8, reward=1, ratio=0.1250)
# │   │   │   │   ├── 2: (action=2, visits=3, reward=1, ratio=0.3333)
# │   │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=2, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=24, reward=1, ratio=0.0417)
# │   │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=2, visits=8, reward=1, ratio=0.1250)
# │   │   │       ├── 5: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=3, visits=3, reward=1, ratio=0.3333)
# │   │   │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=0, visits=21, reward=0, ratio=0.0000)
# │   │       ├── 1: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │       │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │       │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │       │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       └── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │           ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │           ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │           ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │           └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   ├── 4: (action=0, visits=79, reward=1, ratio=0.0127)
# │   │   ├── 8: (action=1, visits=22, reward=1, ratio=0.0455)
# │   │   │   ├── 8: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 12: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   ├── 9: (action=2, visits=7, reward=1, ratio=0.1429)
# │   │   │   │   ├── 13: (action=1, visits=3, reward=1, ratio=0.3333)
# │   │   │   │   │   ├── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 4: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=0, visits=19, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 5: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=19, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   └── 5: (action=2, visits=18, reward=0, ratio=0.0000)
# │   ├── 5: (action=2, visits=73, reward=0, ratio=0.0000)
# │   └── 8: (action=1, visits=8755, reward=8569, ratio=0.9788)
# │       ├── 4: (action=3, visits=18, reward=0, ratio=0.0000)
# │       │   ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
# │       │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 5: (action=2, visits=4, reward=0, ratio=0.0000)
# │       │   ├── 8: (action=1, visits=4, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   └── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │       │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │       ├── 8: (action=0, visits=18, reward=0, ratio=0.0000)
# │       │   ├── 4: (action=3, visits=5, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 9: (action=2, visits=4, reward=0, ratio=0.0000)
# │       │   │   ├── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   ├── 8: (action=0, visits=4, reward=0, ratio=0.0000)
# │       │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │       │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │       │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │       │   └── 12: (action=1, visits=4, reward=0, ratio=0.0000)
# │       ├── 12: (action=1, visits=18, reward=0, ratio=0.0000)
# │       └── 9: (action=2, visits=8700, reward=8569, ratio=0.9849)
# │           ├── 10: (action=2, visits=8655, reward=8558, ratio=0.9888)
# │           │   ├── 9: (action=0, visits=11, reward=1, ratio=0.0909)
# │           │   │   ├── 8: (action=0, visits=2, reward=0, ratio=0.0000)
# │           │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │   │   ├── 5: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │   │   ├── 10: (action=2, visits=4, reward=1, ratio=0.2500)
# │           │   │   │   ├── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │           │   │   │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │   │   │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │   │   └── 13: (action=1, visits=2, reward=0, ratio=0.0000)
# │           │   │       └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │   ├── 6: (action=3, visits=11, reward=1, ratio=0.0909)
# │           │   │   ├── 5: (action=0, visits=2, reward=0, ratio=0.0000)
# │           │   │   ├── 2: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │   │   ├── 7: (action=2, visits=2, reward=0, ratio=0.0000)
# │           │   │   └── 10: (action=1, visits=4, reward=1, ratio=0.2500)
# │           │   │       ├── 14: (action=1, visits=1, reward=1, ratio=1.0000)
# │           │   │       ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │   │       └── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │   ├── 11: (action=2, visits=9, reward=0, ratio=0.0000)
# │           │   └── 14: (action=1, visits=8623, reward=8556, ratio=0.9922)
# │           │       ├── 15: (action=2, visits=5718, reward=5718, ratio=1.0000)
# │           │       ├── 10: (action=3, visits=11, reward=1, ratio=0.0909)
# │           │       │   ├── 9: (action=0, visits=4, reward=1, ratio=0.2500)
# │           │       │   │   ├── 10: (action=2, visits=1, reward=1, ratio=1.0000)
# │           │       │   │   ├── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │       │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │           │       │   ├── 11: (action=2, visits=2, reward=0, ratio=0.0000)
# │           │       │   ├── 6: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │       │   │   └── 5: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │       │   └── 14: (action=1, visits=2, reward=0, ratio=0.0000)
# │           │       │       └── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │       ├── 13: (action=0, visits=11, reward=1, ratio=0.0909)
# │           │       │   ├── 12: (action=0, visits=3, reward=0, ratio=0.0000)
# │           │       │   ├── 14: (action=2, visits=3, reward=0, ratio=0.0000)
# │           │       │   │   ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │       │   │   └── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │       │   ├── 9: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │       │   │   └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │       │   └── 13: (action=1, visits=2, reward=0, ratio=0.0000)
# │           │       │       └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │       └── 14: (action=1, visits=2882, reward=2835, ratio=0.9837)
# │           │           ├── 14: (action=1, visits=805, reward=774, ratio=0.9615)
# │           │           │   ├── 10: (action=3, visits=9, reward=2, ratio=0.2222)
# │           │           │   │   ├── 6: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │           │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   ├── 14: (action=1, visits=4, reward=2, ratio=0.5000)
# │           │           │   │   │   ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   ├── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │           │           │   │   │   └── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   └── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │           │   ├── 15: (action=2, visits=616, reward=616, ratio=1.0000)
# │           │           │   ├── 14: (action=1, visits=170, reward=153, ratio=0.9000)
# │           │           │   │   ├── 14: (action=1, visits=37, reward=30, ratio=0.8108)
# │           │           │   │   │   ├── 14: (action=1, visits=10, reward=7, ratio=0.7000)
# │           │           │   │   │   │   ├── 10: (action=3, visits=2, reward=1, ratio=0.5000)
# │           │           │   │   │   │   │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   │   ├── 15: (action=2, visits=3, reward=3, ratio=1.0000)
# │           │           │   │   │   │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   │   └── 14: (action=1, visits=3, reward=2, ratio=0.6667)
# │           │           │   │   │   │       ├── 14: (action=1, visits=1, reward=1, ratio=1.0000)
# │           │           │   │   │   │       └── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   ├── 13: (action=0, visits=2, reward=0, ratio=0.0000)
# │           │           │   │   │   │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   ├── 15: (action=2, visits=22, reward=22, ratio=1.0000)
# │           │           │   │   │   └── 10: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │           │   │   │       └── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   ├── 15: (action=2, visits=122, reward=122, ratio=1.0000)
# │           │           │   │   ├── 10: (action=3, visits=4, reward=0, ratio=0.0000)
# │           │           │   │   │   ├── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   ├── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   │   └── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   └── 13: (action=0, visits=6, reward=1, ratio=0.1667)
# │           │           │   │       ├── 14: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │           │   │       ├── 12: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │       ├── 13: (action=1, visits=2, reward=1, ratio=0.5000)
# │           │           │   │       │   └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │           │           │   │       └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   └── 13: (action=0, visits=9, reward=2, ratio=0.2222)
# │           │           │       ├── 13: (action=1, visits=3, reward=1, ratio=0.3333)
# │           │           │       │   ├── 13: (action=1, visits=1, reward=1, ratio=1.0000)
# │           │           │       │   └── 12: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │       ├── 12: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │       ├── 14: (action=2, visits=3, reward=1, ratio=0.3333)
# │           │           │       │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │       │   └── 14: (action=1, visits=1, reward=0, ratio=0.0000)
# │           │           │       └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           ├── 15: (action=2, visits=2058, reward=2058, ratio=1.0000)
# │           │           ├── 10: (action=3, visits=9, reward=1, ratio=0.1111)
# │           │           │   ├── 14: (action=1, visits=3, reward=1, ratio=0.3333)
# │           │           │   │   ├── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │           │   │   └── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   ├── 11: (action=2, visits=2, reward=0, ratio=0.0000)
# │           │           │   ├── 9: (action=0, visits=2, reward=0, ratio=0.0000)
# │           │           │   │   └── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           │   └── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           └── 13: (action=0, visits=9, reward=1, ratio=0.1111)
# │           │               ├── 12: (action=0, visits=2, reward=0, ratio=0.0000)
# │           │               ├── 14: (action=2, visits=3, reward=1, ratio=0.3333)
# │           │               │   ├── 14: (action=1, visits=1, reward=1, ratio=1.0000)
# │           │               │   └── 13: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │               ├── 9: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │               │   └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │               └── 13: (action=1, visits=1, reward=0, ratio=0.0000)
# │           ├── 5: (action=3, visits=9, reward=0, ratio=0.0000)
# │           ├── 13: (action=1, visits=26, reward=11, ratio=0.4231)
# │           │   ├── 9: (action=3, visits=3, reward=0, ratio=0.0000)
# │           │   │   ├── 5: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │   ├── 12: (action=0, visits=3, reward=0, ratio=0.0000)
# │           │   ├── 13: (action=1, visits=3, reward=0, ratio=0.0000)
# │           │   │   ├── 12: (action=0, visits=1, reward=0, ratio=0.0000)
# │           │   │   └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │   └── 14: (action=2, visits=16, reward=11, ratio=0.6875)
# │           │       ├── 13: (action=0, visits=2, reward=0, ratio=0.0000)
# │           │       │   └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │       ├── 15: (action=2, visits=8, reward=8, ratio=1.0000)
# │           │       ├── 10: (action=3, visits=2, reward=0, ratio=0.0000)
# │           │       │   └── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │           │       └── 14: (action=1, visits=3, reward=2, ratio=0.6667)
# │           │           ├── 10: (action=3, visits=1, reward=0, ratio=0.0000)
# │           │           └── 15: (action=2, visits=1, reward=1, ratio=1.0000)
# │           └── 8: (action=0, visits=9, reward=0, ratio=0.0000)
# │               ├── 9: (action=2, visits=2, reward=0, ratio=0.0000)
# │               │   └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │               ├── 8: (action=0, visits=2, reward=0, ratio=0.0000)
# │               │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │               ├── 4: (action=3, visits=2, reward=0, ratio=0.0000)
# │               │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │               └── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# ├── 1: (action=2, visits=279, reward=1, ratio=0.0036)
# │   ├── 1: (action=3, visits=68, reward=0, ratio=0.0000)
# │   │   ├── 5: (action=1, visits=17, reward=0, ratio=0.0000)
# │   │   ├── 1: (action=3, visits=17, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=0, visits=17, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   └── 2: (action=2, visits=16, reward=0, ratio=0.0000)
# │   │       ├── 3: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 1: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 2: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       └── 6: (action=1, visits=3, reward=0, ratio=0.0000)
# │   │           ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │           └── 7: (action=2, visits=1, reward=0, ratio=0.0000)
# │   ├── 2: (action=2, visits=74, reward=1, ratio=0.0135)
# │   │   ├── 2: (action=3, visits=18, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 3: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 6: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 6: (action=1, visits=21, reward=1, ratio=0.0476)
# │   │   │   ├── 7: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=3, visits=7, reward=1, ratio=0.1429)
# │   │   │   │   ├── 6: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 10: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 10: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 6: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 11: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 9: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 3: (action=2, visits=17, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 3: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 3: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 7: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   └── 1: (action=0, visits=17, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 5: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │       ├── 2: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       └── 1: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │           ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │           ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │           └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   ├── 0: (action=0, visits=68, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=1, visits=17, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 4: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 1: (action=2, visits=17, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=17, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=3, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   └── 0: (action=0, visits=16, reward=0, ratio=0.0000)
# │   │       ├── 4: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 1: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       └── 0: (action=3, visits=3, reward=0, ratio=0.0000)
# │   │           ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │           └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   └── 5: (action=1, visits=68, reward=0, ratio=0.0000)
# ├── 0: (action=3, visits=368, reward=9, ratio=0.0245)
# │   ├── 1: (action=2, visits=84, reward=1, ratio=0.0119)
# │   │   ├── 1: (action=3, visits=20, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   └── 2: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=0, visits=20, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 2: (action=2, visits=23, reward=1, ratio=0.0435)
# │   │   │   ├── 3: (action=2, visits=7, reward=1, ratio=0.1429)
# │   │   │   │   ├── 3: (action=2, visits=3, reward=1, ratio=0.3333)
# │   │   │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 7: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 6: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 7: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 2: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │       ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   └── 5: (action=1, visits=20, reward=0, ratio=0.0000)
# │   ├── 0: (action=3, visits=83, reward=1, ratio=0.0120)
# │   │   ├── 4: (action=1, visits=23, reward=1, ratio=0.0435)
# │   │   │   ├── 4: (action=0, visits=7, reward=1, ratio=0.1429)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=3, reward=1, ratio=0.3333)
# │   │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 5: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=20, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 1: (action=2, visits=4, reward=0, ratio=0.0000)
# │   │   │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 1: (action=2, visits=20, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 2: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 5: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │   └── 0: (action=0, visits=19, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 1: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │       │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │       ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
# │   │       │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │       └── 4: (action=1, visits=4, reward=0, ratio=0.0000)
# │   │           ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │           ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │           └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   ├── 4: (action=1, visits=103, reward=4, ratio=0.0388)
# │   │   ├── 8: (action=1, visits=26, reward=1, ratio=0.0385)
# │   │   │   ├── 8: (action=0, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 9: (action=2, visits=8, reward=1, ratio=0.1250)
# │   │   │   │   ├── 8: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 13: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 9: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 5: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   └── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 12: (action=1, visits=6, reward=0, ratio=0.0000)
# │   │   │   └── 4: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 0: (action=3, visits=22, reward=0, ratio=0.0000)
# │   │   │   ├── 0: (action=0, visits=6, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 1: (action=2, visits=5, reward=0, ratio=0.0000)
# │   │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   └── 0: (action=3, visits=5, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   ├── 4: (action=0, visits=33, reward=3, ratio=0.0909)
# │   │   │   ├── 0: (action=3, visits=7, reward=0, ratio=0.0000)
# │   │   │   │   ├── 4: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 8: (action=1, visits=13, reward=3, ratio=0.2308)
# │   │   │   │   ├── 8: (action=0, visits=4, reward=1, ratio=0.2500)
# │   │   │   │   │   ├── 9: (action=2, visits=1, reward=1, ratio=1.0000)
# │   │   │   │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   ├── 12: (action=1, visits=2, reward=0, ratio=0.0000)
# │   │   │   │   ├── 9: (action=2, visits=3, reward=1, ratio=0.3333)
# │   │   │   │   │   ├── 10: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   │   └── 8: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   │   └── 4: (action=3, visits=3, reward=1, ratio=0.3333)
# │   │   │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │   │       └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │   ├── 5: (action=2, visits=6, reward=0, ratio=0.0000)
# │   │   │   └── 4: (action=0, visits=6, reward=0, ratio=0.0000)
# │   │   │       ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
# │   │   │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
# │   │   │       ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
# │   │   │       └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
# ...
#     │   │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 4: (action=1, visits=8, reward=1, ratio=0.1250)
#     │   │   │   ├── 5: (action=2, visits=2, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=3, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=0, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 0: (action=0, visits=5, reward=0, ratio=0.0000)
#     │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   └── 0: (action=0, visits=20, reward=0, ratio=0.0000)
#     │       ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
#     │       │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       ├── 1: (action=2, visits=5, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#     │       │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       └── 4: (action=1, visits=4, reward=0, ratio=0.0000)
#     │           ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │           ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#     │           └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#     ├── 0: (action=0, visits=81, reward=1, ratio=0.0123)
#     │   ├── 4: (action=1, visits=19, reward=0, ratio=0.0000)
#     │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 8: (action=1, visits=4, reward=0, ratio=0.0000)
#     │   │   │   ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 9: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 5: (action=2, visits=4, reward=0, ratio=0.0000)
#     │   ├── 1: (action=2, visits=19, reward=0, ratio=0.0000)
#     │   │   ├── 5: (action=1, visits=5, reward=0, ratio=0.0000)
#     │   │   ├── 2: (action=2, visits=5, reward=0, ratio=0.0000)
#     │   │   │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 1: (action=3, visits=4, reward=0, ratio=0.0000)
#     │   │       ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │       └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   ├── 0: (action=3, visits=19, reward=0, ratio=0.0000)
#     │   │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 0: (action=0, visits=4, reward=0, ratio=0.0000)
#     │   │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 1: (action=2, visits=4, reward=0, ratio=0.0000)
#     │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │       └── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   └── 0: (action=0, visits=23, reward=1, ratio=0.0435)
#     │       ├── 4: (action=1, visits=7, reward=1, ratio=0.1429)
#     │       │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 0: (action=3, visits=3, reward=1, ratio=0.3333)
#     │       │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       ├── 1: (action=2, visits=5, reward=0, ratio=0.0000)
#     │       │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       └── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#     │           ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │           ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │           ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │           └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     ├── 1: (action=2, visits=101, reward=4, ratio=0.0396)
#     │   ├── 0: (action=0, visits=25, reward=1, ratio=0.0400)
#     │   │   ├── 0: (action=0, visits=8, reward=1, ratio=0.1250)
#     │   │   │   ├── 1: (action=2, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 4: (action=1, visits=3, reward=1, ratio=0.3333)
#     │   │   │       ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │       └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 1: (action=2, visits=6, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=0, visits=2, reward=0, ratio=0.0000)
#     │   │   │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 4: (action=1, visits=5, reward=0, ratio=0.0000)
#     │   │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#     │   │       ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │       └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   ├── 5: (action=1, visits=21, reward=0, ratio=0.0000)
#     │   ├── 2: (action=2, visits=29, reward=2, ratio=0.0690)
#     │   │   ├── 6: (action=1, visits=6, reward=0, ratio=0.0000)
#     │   │   │   ├── 7: (action=2, visits=2, reward=0, ratio=0.0000)
#     │   │   │   ├── 10: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 5: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 1: (action=0, visits=6, reward=0, ratio=0.0000)
#     │   │   │   ├── 5: (action=1, visits=2, reward=0, ratio=0.0000)
#     │   │   │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   ├── 3: (action=2, visits=8, reward=1, ratio=0.1250)
#     │   │   │   ├── 7: (action=1, visits=2, reward=0, ratio=0.0000)
#     │   │   │   ├── 2: (action=0, visits=1, reward=0, ratio=0.0000)
#     │   │   │   ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   │   └── 3: (action=3, visits=3, reward=1, ratio=0.3333)
#     │   │   │       ├── 7: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │   │       └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │   └── 2: (action=3, visits=8, reward=1, ratio=0.1250)
#     │   │       ├── 1: (action=0, visits=3, reward=1, ratio=0.3333)
#     │   │       │   ├── 2: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │       │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 6: (action=1, visits=2, reward=0, ratio=0.0000)
#     │   │       │   └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   │       ├── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │   │       └── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │   └── 1: (action=3, visits=25, reward=1, ratio=0.0400)
#     │       ├── 5: (action=1, visits=6, reward=0, ratio=0.0000)
#     │       ├── 2: (action=2, visits=5, reward=0, ratio=0.0000)
#     │       │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 6: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 3: (action=2, visits=1, reward=0, ratio=0.0000)
#     │       ├── 1: (action=3, visits=8, reward=1, ratio=0.1250)
#     │       │   ├── 2: (action=2, visits=3, reward=1, ratio=0.3333)
#     │       │   │   ├── 2: (action=3, visits=1, reward=0, ratio=0.0000)
#     │       │   │   └── 1: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 1: (action=3, visits=2, reward=0, ratio=0.0000)
#     │       │   │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │       │   └── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#     │       └── 0: (action=0, visits=5, reward=0, ratio=0.0000)
#     │           ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#     │           ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#     │           ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#     │           └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#     └── 4: (action=1, visits=75, reward=0, ratio=0.0000)
#         ├── 4: (action=0, visits=19, reward=0, ratio=0.0000)
#         │   ├── 4: (action=0, visits=5, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#         │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   ├── 5: (action=2, visits=4, reward=0, ratio=0.0000)
#         │   └── 8: (action=1, visits=4, reward=0, ratio=0.0000)
#         │       ├── 4: (action=3, visits=1, reward=0, ratio=0.0000)
#         │       ├── 9: (action=2, visits=1, reward=0, ratio=0.0000)
#         │       └── 12: (action=1, visits=1, reward=0, ratio=0.0000)
#         ├── 0: (action=3, visits=19, reward=0, ratio=0.0000)
#         │   ├── 0: (action=3, visits=5, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   ├── 0: (action=0, visits=5, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 1: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 4: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   ├── 4: (action=1, visits=4, reward=0, ratio=0.0000)
#         │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 4: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   └── 1: (action=2, visits=4, reward=0, ratio=0.0000)
#         │       ├── 5: (action=1, visits=1, reward=0, ratio=0.0000)
#         │       ├── 1: (action=3, visits=1, reward=0, ratio=0.0000)
#         │       └── 0: (action=0, visits=1, reward=0, ratio=0.0000)
#         ├── 8: (action=1, visits=18, reward=0, ratio=0.0000)
#         │   ├── 9: (action=2, visits=5, reward=0, ratio=0.0000)
#         │   │   ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 10: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 13: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 5: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   ├── 4: (action=3, visits=4, reward=0, ratio=0.0000)
#         │   │   ├── 8: (action=1, visits=1, reward=0, ratio=0.0000)
#         │   │   ├── 5: (action=2, visits=1, reward=0, ratio=0.0000)
#         │   │   └── 0: (action=3, visits=1, reward=0, ratio=0.0000)
#         │   ├── 12: (action=1, visits=4, reward=0, ratio=0.0000)
#         │   └── 8: (action=0, visits=4, reward=0, ratio=0.0000)
#         │       ├── 8: (action=0, visits=1, reward=0, ratio=0.0000)
#         │       ├── 12: (action=1, visits=1, reward=0, ratio=0.0000)
#         │       └── 9: (action=2, visits=1, reward=0, ratio=0.0000)
#         └── 5: (action=2, visits=18, reward=0, ratio=0.0000)
#
# ****** 4 ******
# 0: 0.0404
# 4: 0.0127
# 5: 0.0000
# 8: 0.9788
# ****** 8 ******
# 4: 0.0000
# 8: 0.0000
# 12: 0.0000
# 9: 0.9849
# ****** 4 ******
# 4: 0.0000
# 5: 0.0000
# 8: 0.0000
# 0: 0.0000
# ****** 5 ******
# Rendering final policy...
#
# Action: Down -> State: 4
# Action: Down -> State: 8
# Action: Right -> State: 9
# Action: Right -> State: 10
# Action: Down -> State: 14
# Action: Right -> State: 15
#
# Final policy path (states): [(0, {'prob': 1}), 4, 8, 9, 10, 14]
# [0, 4, 8, 9, 10, 14]

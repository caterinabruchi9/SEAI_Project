# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

def create_env():
    return gym.make('FrozenLake-v1', is_slippery=False)

def initialize_q_table(env):
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    return np.zeros((number_of_states, number_of_actions))

def decay_function(episode, total_train_episodes, min_epsilon=0.01):
    return max(min_epsilon, min(1.0, 1.0 - np.log10((episode + 1) / (total_train_episodes * 0.1))))

def choose_action(q_table, state, epsilon, env):
    print(f"State before accessing q_table: {state}")
    if np.random.random() <= epsilon:
        action = env.action_space.sample()  # Exploration policy (behavior policy)
    else:
        action = np.argmax(q_table[state])  # Exploitation Greedy policy (target policy)
    print(f"Action chosen: {action}")
    return action

def generate_episode(behavior_policy, q_table, env, max_env_steps):
    state = env.reset()
    total_reward = 0
    done = False
    trajectory = []
    
    if isinstance(state, tuple):  # Normalizzazione iniziale dello stato
        state = state[0]
    
    while not done:
        action = behavior_policy(q_table, state, env)
        # Aggiorna qui: estrai il primo elemento dello stato se è una tupla
        new_state, reward, done, info, _ = env.step(action)
        if isinstance(new_state, tuple):
            new_state = new_state[0]  # Estrarre solo il componente stato intero
        trajectory.append((state, action, reward))
        state = new_state
        total_reward += reward
        if done:
            break
    
    return trajectory, total_reward


def Monte_Carlo(env, total_train_episodes, gamma, max_epsilon, min_epsilon):
    q_table = initialize_q_table(env)
    visits_counter = np.zeros_like(q_table)
    rewards = []
    max_env_steps = env.spec.max_episode_steps

    for episode in range(total_train_episodes):
        print('\nSTART EPISODE:', episode)
        epsilon = decay_function(episode, total_train_episodes, min_epsilon)
        print('\nEPSILON:', epsilon)
        behavior_policy = lambda q, s, e: choose_action(q, s, epsilon, e)
        trajectory, total_reward = generate_episode(behavior_policy, q_table, env, max_env_steps)
        G = 0
        W = 1  # Weight for importance sampling

        for t in reversed(range(len(trajectory))):
            state, action, reward = trajectory[t]
            G = gamma * G + reward
            
            visits_counter[state, action] += 1
            q_table[state, action] += (W / visits_counter[state, action]) * (G - q_table[state, action])
            
            if action != np.argmax(q_table[state]):
                break  # Break if the action taken is not the same as the action under the target policy
            W *= 1. / (0.5 if np.random.random() > epsilon else 0.5)  # Adjust the weight for the sampled policy

        rewards.append(total_reward)
        if episode % 50 == 0:
            print(f"Episode {episode}, epsilon {epsilon:.4f}, reward {total_reward:.2f}")

    return q_table, rewards

def plot_rewards(rewards):
    x = np.linspace(0, len(rewards) * 50, len(rewards))
    plt.plot(x, rewards, label='Monte Carlo Off-Policy')
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.legend()
    plt.show()

def test_policy(env, q_table, num_episodes=10):
    rewards = []
    max_env_steps = env.spec.max_episode_steps

    for episode in range(num_episodes):
        state = env.reset()
        total_rewards = 0
        done = False

        while not done:
            action = np.argmax(q_table[state])
            state, reward, done, info, _ = env.step(action)
            total_rewards += reward
            if done:
                break

        rewards.append(total_rewards)

    return np.mean(rewards)

if __name__ == "__main__":
    env = create_env()
    total_train_episodes = 500
    gamma = 0.99
    max_epsilon = 1.0
    min_epsilon = 0.01

    q_table, rewards = Monte_Carlo(env, total_train_episodes, gamma, max_epsilon, min_epsilon)
    #plot_rewards(rewards)

    # average_reward = test_policy(env, q_table)
    #print(f"Average Reward: {average_reward}")
    env.close()
# Out:
# START EPISODE: 0
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
# Episode 0, epsilon 1.0000, reward 0.00
#
# START EPISODE: 1
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 2
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 3
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 4
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 5
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 6
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 7
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 8
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 9
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 10
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 11
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 12
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 13
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 3
#
# START EPISODE: 14
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 15
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 16
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 3
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 17
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 0
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 0
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 0
#
# START EPISODE: 18
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 19
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 20
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 21
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 22
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 23
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 24
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 25
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 26
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 27
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 28
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 29
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 30
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 31
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 32
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 33
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 3
# State before accessing q_table: 3
# Action chosen: 3
# State before accessing q_table: 3
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 0
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 34
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 35
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 36
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 37
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 38
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 39
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 40
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 41
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 42
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 43
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 3
#
# START EPISODE: 44
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 45
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 46
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 0
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 47
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 48
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 49
#
# EPSILON: 1.0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 0
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 3
# State before accessing q_table: 3
# Action chosen: 3
# State before accessing q_table: 3
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 50
#
# EPSILON: 0.9913998282380825
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 3
# Episode 50, epsilon 0.9914, reward 0.00
#
# START EPISODE: 51
#
# EPSILON: 0.9829666607012196
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 52
#
# EPSILON: 0.9746941347352297
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 2
#
# START EPISODE: 53
#
# EPSILON: 0.9665762445130502
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 54
#
# EPSILON: 0.958607314841775
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 55
#
# EPSILON: 0.9507819773298184
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 56
#
# EPSILON: 0.9430951486635274
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 57
#
# EPSILON: 0.9355420107730815
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 58
#
# EPSILON: 0.9281179926938746
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 2
#
# START EPISODE: 59
#
# EPSILON: 0.9208187539523752
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 0
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 0
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 60
#
# EPSILON: 0.9136401693252518
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 61
#
# EPSILON: 0.906578314837765
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 62
#
# EPSILON: 0.8996294548824371
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 63
#
# EPSILON: 0.8927900303521317
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 64
#
# EPSILON: 0.8860566476931632
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 65
#
# EPSILON: 0.8794260687941501
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 66
#
# EPSILON: 0.8728952016351923
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 67
#
# EPSILON: 0.8664610916297825
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 68
#
# EPSILON: 0.8601209135987635
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 3
#
# START EPISODE: 69
#
# EPSILON: 0.853871964321762
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 70
#
# EPSILON: 0.8477116556169435
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 71
#
# EPSILON: 0.8416375079047503
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 72
#
# EPSILON: 0.8356471442155629
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 0
#
# START EPISODE: 73
#
# EPSILON: 0.8297382846050426
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 74
#
# EPSILON: 0.8239087409443188
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 75
#
# EPSILON: 0.8181564120552275
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 0
# State before accessing q_table: 9
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 76
#
# EPSILON: 0.8124792791635369
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 3
# State before accessing q_table: 3
# Action chosen: 0
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 3
# State before accessing q_table: 10
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 3
# State before accessing q_table: 10
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 2
#
# START EPISODE: 77
#
# EPSILON: 0.8068754016455384
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 0
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 78
#
# EPSILON: 0.8013429130455774
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 79
#
# EPSILON: 0.7958800173440752
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 80
#
# EPSILON: 0.790484985457369
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 81
#
# EPSILON: 0.7851561519523022
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 3
#
# START EPISODE: 82
#
# EPSILON: 0.7798919119599449
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 83
#
# EPSILON: 0.7746907182741372
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 0
#
# START EPISODE: 84
#
# EPSILON: 0.7695510786217261
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 0
#
# START EPISODE: 85
#
# EPSILON: 0.7644715530924511
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 86
#
# EPSILON: 0.7594507517174003
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 87
#
# EPSILON: 0.7544873321858502
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 3
# State before accessing q_table: 3
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 88
#
# EPSILON: 0.749579997691106
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 89
#
# EPSILON: 0.744727494896694
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 90
#
# EPSILON: 0.7399286120149252
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 91
#
# EPSILON: 0.7351821769904635
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 0
# State before accessing q_table: 13
# Action chosen: 3
# State before accessing q_table: 9
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 2
# State before accessing q_table: 9
# Action chosen: 1
# State before accessing q_table: 13
# Action chosen: 0
#
# START EPISODE: 92
#
# EPSILON: 0.7304870557820837
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 1
#
# START EPISODE: 93
#
# EPSILON: 0.7258421507363202
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 94
#
# EPSILON: 0.7212463990471711
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 95
#
# EPSILON: 0.7166987712964504
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 3
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 96
#
# EPSILON: 0.712198270069774
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 97
#
# EPSILON: 0.707743928643524
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 2
# State before accessing q_table: 3
# Action chosen: 1
#
# START EPISODE: 98
#
# EPSILON: 0.7033348097384688
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 0
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 99
#
# EPSILON: 0.6989700043360187
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 100
#
# EPSILON: 0.6946486305533762
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
# Episode 100, epsilon 0.6946, reward 0.00
#
# START EPISODE: 101
#
# EPSILON: 0.6903698325741012
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 3
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 1
# State before accessing q_table: 10
# Action chosen: 1
# State before accessing q_table: 14
# Action chosen: 2
#
# START EPISODE: 102
#
# EPSILON: 0.6861327796308465
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 0
#
# START EPISODE: 103
#
# EPSILON: 0.6819366650372385
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 1
#
# START EPISODE: 104
#
# EPSILON: 0.6777807052660807
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 2
#
# START EPISODE: 105
#
# EPSILON: 0.6736641390712486
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 2
# State before accessing q_table: 2
# Action chosen: 1
# State before accessing q_table: 6
# Action chosen: 2
#
# START EPISODE: 106
#
# EPSILON: 0.6695862266508091
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 3
# State before accessing q_table: 4
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 2
# State before accessing q_table: 1
# Action chosen: 0
# State before accessing q_table: 0
# ...
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 3
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 0
# State before accessing q_table: 0
# Action chosen: 1
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 0
# State before accessing q_table: 4
# Action chosen: 1
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 0
# State before accessing q_table: 8
# Action chosen: 1
